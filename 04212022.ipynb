# %% [markdown]
# <a href="https://colab.research.google.com/github/signnd/prak-ml/blob/main/04212022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported')
# Out:
# Modules are imported

# %%
corona_dataset_csv = pd.read_csv('/content/drive/My Drive/Machine Learning/covid19_Confirmed_dataset.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %%
corona_dataset_csv.drop(['Lat','Long'], axis = 1, inplace=True)

# %%
corona_dataset_csv.head(100)
# Out:
#    Province/State      Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0             NaN         Afghanistan        0        0        0        0
# 1             NaN             Albania        0        0        0        0
# 2             NaN             Algeria        0        0        0        0
# 3             NaN             Andorra        0        0        0        0
# 4             NaN              Angola        0        0        0        0
# ..            ...                 ...      ...      ...      ...      ...
# 95            NaN            Djibouti        0        0        0        0
# 96            NaN  Dominican Republic        0        0        0        0
# 97            NaN             Ecuador        0        0        0        0
# 98            NaN               Egypt        0        0        0        0
# 99            NaN         El Salvador        0        0        0        0
#
#     1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  \
# ...

# %% [markdown]
# corona_dataset_aggregated = corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_aggregated.head(100)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
# ...                 ...      ...      ...      ...      ...      ...      ...
# Laos                  0        0        0        0        0        0        0
# Latvia                0        0        0        0        0        0        0
# Lebanon               0        0        0        0        0        0        0
# Liberia               0        0        0        0        0        0        0
# Libya                 0        0        0        0        0        0        0
#
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# corona_dataset_aggregated.loc['Indonesia'].plot()
# plt.legend()

# %%
corona_dataset_aggregated.loc['Algeria'].plot()
corona_dataset_aggregated.loc['Angola'].plot()
corona_dataset_aggregated.loc['Andorra'].plot()
corona_dataset_aggregated.loc['Indonesia'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['China'].diff()
# Out:
# 1/22/20      NaN
# 1/23/20     95.0
# 1/24/20    277.0
# 1/25/20    486.0
# 1/26/20    669.0
#            ...
# 4/26/20      3.0
# 4/27/20      6.0
# 4/28/20     22.0
# 4/29/20      4.0
# 4/30/20     12.0
# Name: China, Length: 100, dtype: float64

# %%
corona_dataset_aggregated.loc['China'].diff().plot()

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = [ ]

for c in countries :
  max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())

corona_dataset_aggregated['max_infection_rates'] = max_infection_rates

# %%
corona_dataset_aggregated.head(200)
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max_infection_rates'])
corona_data.head(187)
# Out:
#                     max_infection_rates
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# ...                                 ...
# West Bank and Gaza                 66.0
# Western Sahara                      4.0
# Yemen                               5.0
# Zambia                              9.0
# Zimbabwe                            8.0
#
# [187 rows x 1 columns]

# %%
happiness_report_csv = pd.read_csv('/content/drive/My Drive/Machine Learning/worldwide_happiness_report.csv')
happiness_report_csv.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
happiness_report_csv.drop(['Overall rank','Score','Generosity','Freedom to make life choices','Perceptions of corruption'], axis = 1, inplace=True)

# %%
happiness_report_csv.set_index('Country or region', inplace=True)

# %%
data = corona_data.join(happiness_report_csv, how = 'inner')
data.head(50)
# Out:
#                           max_infection_rates  GDP per capita  Social support  \
# Afghanistan                             232.0           0.350           0.517
# Albania                                  34.0           0.947           0.848
# Algeria                                 199.0           1.002           1.160
# Argentina                               291.0           1.092           1.432
# Armenia                                 134.0           0.850           1.055
# Australia                               497.0           1.372           1.548
# Austria                                1321.0           1.376           1.475
# Azerbaijan                              105.0           1.043           1.147
# Bahrain                                 301.0           1.362           1.368
# Bangladesh                              641.0           0.562           0.928
# Belarus                                1485.0           1.067           1.465
# ...

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999

# %%
data.corr()
# Out:
#                          max_infection_rates  GDP per capita  Social support  \
# max_infection_rates                 1.000000        0.250118        0.191958
# GDP per capita                      0.250118        1.000000        0.759468
# Social support                      0.191958        0.759468        1.000000
# Healthy life expectancy             0.289263        0.863062        0.765286
#
#                          Healthy life expectancy
# max_infection_rates                     0.289263
# GDP per capita                          0.863062
# Social support                          0.765286
# Healthy life expectancy                 1.000000

# %%
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy
# Afghanistan                    0.361
# Albania                        0.874
# Algeria                        0.785
# Argentina                      0.881
# Armenia                        0.815

# %%
x = data['Social support']
y = data['max_infection_rates']
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
